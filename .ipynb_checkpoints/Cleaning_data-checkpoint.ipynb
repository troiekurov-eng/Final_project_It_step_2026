# %%
import pandas as pd

# %%
df = pd.read_csv('asts.csv', sep=',', on_bad_lines='skip')

# %%
df.head(3)

# %%
df.tail(3)

# %%
df.sample(3)

# %%
df['Vendor'].astype(str).isnull().sum()

# %%
df['Vendor'].astype(str).isnull().mean()

# %%
df.astype(str).isnull().mean()
